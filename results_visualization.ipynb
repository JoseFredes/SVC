# %%
import pandas as pd

# %%
acc_results = pd.DataFrame({'q3': [0.9583333333333334], 'q4': [0.8013333333333333]})
acc_results.plot.bar().set_title('Accuracy of the model on the test set').set_fontsize(20).set_fontweight('bold').set_color('black').
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 acc_results = pd.DataFrame({'q3': [0.9583333333333334], 'q4': [0.8013333333333333]})
# ----> 2 acc_results.plot.bar().set_title('Accuracy of the model on the test set').set_fontsize(20).set_fontweight('bold').set_color('black').set_fontname('Arial').set_position([0.5, 1.05]).set_size(20).set_weight('bold').set_color('black').set_fontname('Arial')
#
# AttributeError: 'NoneType' object has no attribute 'set_fontweight'
